# %% [markdown]
# <a href="https://colab.research.google.com/github/duplex143/SLAF/blob/patch-1/cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.11
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.11`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# !git clone --single-branch --branch r1.11 https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 19105, done.
# remote: Total 19105 (delta 0), reused 0 (delta 0), pack-reused 19105
# Receiving objects: 100% (19105/19105), 502.81 MiB | 15.04 MiB/s, done.
# Resolving deltas: 100% (10745/10745), done.

# %%
# !python cifar10_download_and_extract.py
# Out:
# WARNING:tensorflow:From cifar10_download_and_extract.py:63: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# >> Downloading cifar-10-binary.tar.gz 100.0%
# Successfully downloaded cifar-10-binary.tar.gz 170052171 bytes.

# %%
# !cp -R /tmp/cifar10_data/cifar-10-batches-bin/* /tmp/cifar10_data

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models'
import sys
sys.path.append('/content/models')

# %%
# !python cifar10_main.py
# Out:
# WARNING:tensorflow:From /content/models/official/utils/logs/hooks.py:28: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From /content/models/official/utils/logs/metric_hook.py:24: The name tf.train.LoggingTensorHook is deprecated. Please use tf.estimator.LoggingTensorHook instead.
#
# WARNING:tensorflow:From cifar10_main.py:264: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From cifar10_main.py:264: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2020-03-30 09:45:24.619253: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-30 09:45:24.619493: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2956bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
